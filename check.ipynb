# %%
import mediapipe as mp
dir(mp)
# Out:
# ['Image',
#  'ImageFormat',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'tasks']

# %%
import mediapipe as mp
print(mp.__version__)
print(hasattr(mp, "solutions"))
# Out:
# 0.10.31
# False

# %%
import mediapipe as mp
from mediapipe import solutions

print("OK")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 import mediapipe as mp
# ----> 2 from mediapipe import solutions
#       4 print("OK")
#
# ImportError: cannot import name 'solutions' from 'mediapipe' (C:\Users\Pranathi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mediapipe\__init__.py)
